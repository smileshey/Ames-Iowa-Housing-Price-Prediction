# %% [markdown]
# # Feature Engineering
#
# This notebook is dedicated to the Engineering of the cleaned features created in the previous notebook.

# %% [markdown]
# ### Imports

# %%
# Library imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from scipy.stats import pearsonr


import pickle

# %%
#data imports
with open('pickles/df.pkl', 'rb') as f:
    df = pickle.load(f)
    
with open('pickles/df_test.pkl', 'rb') as f:
    df_test = pickle.load(f)

# variable import
with open('pickles/corr_list.pkl', 'rb') as f:
    corr_list = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #data imports
#       2 with open('pickles/df.pkl', 'rb') as f:
# ----> 3     df = pickle.load(f)
#       5 with open('pickles/df_test.pkl', 'rb') as f:
#       6     df_test = pickle.load(f)
#
# NameError: name 'pickle' is not defined

# %% [markdown]
# #### Standardizing Continuous Features (Using StandardScaler)
#
# The remaining features will be numeric (continuous) features, which I will be analyzing to determine if specific features would benefit from scaling. There are 39 features within this dataframe and I will preliminarily look into the top 10 continuous features (by correlation with sale price).

# %%
# Finding continuous features

#train
df_continuous = df.select_dtypes(include=[np.number])
df_continuous = df_continuous.loc[:, df_continuous.columns.isin(corr_list)]

#test
df_test_continuous = df_test.select_dtypes(include=[np.number])
df_test_continuous = df_test_continuous.loc[:, df_test_continuous.columns.isin(corr_list)]

# setting up Standard Scaler
scaler = StandardScaler()
#train
df_scaled = scaler.fit_transform(df_continuous)
#test
df_test_scaled = scaler.transform(df_test_continuous)

# returning scaled df
#train
df_scaled = pd.DataFrame(df_scaled, columns=df_continuous.columns)

#test
df_scaled_test = pd.DataFrame(df_test_scaled, columns=df_test_continuous.columns)

# Pulling only corr_list columns
df_scaled_final = df_scaled[corr_list]
df_scaled_test_final = df_scaled_test[corr_list]

df_scaled = df_scaled_final
df_test_scaled = df_scaled_test_final

#fixing weird error where above code creates 2 of every column
df_scaled = df_scaled.loc[:, ~df_scaled.columns.duplicated(keep='last')]
df_test_scaled = df_test_scaled.loc[:, ~df_test_scaled.columns.duplicated(keep='last')]
# Out:
# (81,)

# %% [markdown]
# #### Hot Encoding Categorical Features (using get dummies)
#
# Since there are a large number of discrete features, I'll need to hot encode them using getdummies() to be able to include them in my model. Below I've displayed a dataframe that includes all of the non-numerical features (discrete data), which will be good candidates for hot encoding.

# %%
# extract the categorical features from the training data
categorical_train = df.select_dtypes(exclude=[np.number])

#display(categorical_train)

# extract the categorical features from the test data
categorical_test = df_test.select_dtypes(exclude=[np.number])

# get the list of categorical columns to encode
cat_cols = categorical_train.columns.tolist()

# use get_dummies to one-hot encode the categorical features
train_encoded = pd.get_dummies(categorical_train, columns=cat_cols)
test_encoded = pd.get_dummies(categorical_test, columns=cat_cols)

# align the columns in the test data to match the columns in the training data
test_encoded = test_encoded.reindex(columns=train_encoded.columns, fill_value=0)


cat_cols_encoded = train_encoded.columns.tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # extract the categorical features from the training data
# ----> 2 categorical_train = df.select_dtypes(exclude=[np.number])
#       4 #display(categorical_train)
#       5
#       6 # extract the categorical features from the test data
#       7 categorical_test = df_test.select_dtypes(exclude=[np.number])
#
# NameError: name 'df' is not defined

# %% [markdown]
# #### Selecting Important Categorical Features (Pearson r)
#
# To prevent the model from being drastically overfit, I want to evaluate a subset of the categorical features. This process will be similar to how we previously evaluated the continuous features by shortening to corr_list.
#
# Since these values are categorical features, I need to use the pearson coefficient to determine the categorical features relationship with the continuous feature of saleprice.

# %%
# since we seperated the two features into two bins, we inadvertently removed the saleprice column. Let's add that back in
# so that we can calculate correlations

price_col = df['saleprice']
train_encoded['saleprice'] = price_col

# Categorical Feature correlation with 'saleprice'
#correlation_encoded = train_encoded

correlations = {}
for feature in train_encoded.columns[:-1]:
    correlation, _ = pearsonr(train_encoded[feature], train_encoded['saleprice'])
    correlations[feature] = correlation

# Sort the features by their correlation values
sorted_features = sorted(correlations.items(), key=lambda x: abs(x[1]), reverse=True)

display(sorted_features)

# Print the sorted feature correlations
for feature, correlation in sorted_features:
    print(f'{feature}: {correlation:.3f}')
# Out:
# [('exter qual_TA', -0.600362043878517),
#  ('bsmt qual_Ex', 0.5864972294603448),
#  ('kitchen qual_Ex', 0.5512844949973906),
#  ('kitchen qual_TA', -0.5408600571106338),
#  ('foundation_PConc', 0.5290468529844162),
#  ('exter qual_Ex', 0.49386101668262444),
#  ('bsmtfin type 1_GLQ', 0.4635488990371297),
#  ('bsmt qual_TA', -0.45697898944878385),
#  ('heating qc_Ex', 0.45325535292868846),
#  ('neighborhood_NridgHt', 0.44864681340299156),
#  ('exter qual_Gd', 0.4466854983075199),
#  ('garage finish_Unf', -0.43222009547586354),
#  ('mas vnr type_None', -0.4240875482859905),
#  ('garage finish_Fin', 0.4229363608708123),
#  ('fireplace qu_Gd', 0.3847321427605365),
#  ('bsmt exposure_Gd', 0.37703175871624217),
#  ('garage type_Detchd', -0.37034443865764893),
#  ('sale type_New', 0.3581019691173568),
#  ('garage type_Attchd', 0.3578790281572793),
#  ('foundation_CBlock', -0.3555352152001199),
#  ('heating qc_TA', -0.343541557917075),
#  ('exterior 1st_VinylSd', 0.3421455585593902),
#  ('exterior 2nd_VinylSd', 0.3375625324636549),
#  ('mas vnr type_Stone', 0.31002603603788986),
#  ('lot shape_Reg', -0.30629082600101676),
#  ('kitchen qual_Gd', 0.30624553121545606),
#  ('bsmt exposure_No', -0.29310596114098736),
#  ('paved drive_Y', 0.2892096014539486),
#  ('ms zoning_RM', -0.2819514318924292),
#  ('central air_Y', 0.2773778061451661),
#  ('central air_N', -0.27737780614516605),
#  ('paved drive_N', -0.2736125469351672),
#  ('lot shape_IR1', 0.27357444442084783),
#  ('garage cond_TA', 0.27184644523323614),
#  ('roof style_Hip', 0.2652241868015648),
#  ('neighborhood_NoRidge', 0.2633952224131245),
#  ('mas vnr type_BrkFace', 0.2579014902689647),
#  ('neighborhood_StoneBr', 0.2569774278175881),
#  ('electrical_SBrkr', 0.25404434643134227),
#  ('garage qual_TA', 0.2497734735502387),
#  ('roof style_Gable', -0.24932901330452917),
#  ('fireplace qu_Ex', 0.23452530566734056),
#  ('ms zoning_RL', 0.23146818258809085),
#  ('foundation_BrkTil', -0.22989140766305233),
#  ('bsmt qual_Gd', 0.226835768455646),
#  ('garage type_BuiltIn', 0.21981995971377544),
#  ('sale type_WD ', -0.21254174769346074),
#  ('land contour_HLS', 0.21224514191683982),
#  ('neighborhood_OldTown', -0.20837101275411152),
#  ('house style_2Story', 0.20191126665443387),
#  ('electrical_FuseA', -0.2012063365214957),
#  ('house style_1.5Fin', -0.19580258408891107),
#  ('exterior 1st_Wd Sdng', -0.19173446228826777),
#  ('neighborhood_NAmes', -0.18938685934090546),
#  ('neighborhood_IDOTRR', -0.18923742256009382),
#  ('garage finish_RFn', 0.18459357354296332),
#  ('neighborhood_Edwards', -0.17611881350859732),
#  ('exterior 2nd_Wd Sdng', -0.1729710026317098),
#  ('garage qual_Fa', -0.16813394352842945),
#  ('exterior 1st_CemntBd', 0.1675130900045818),
#  ('lot config_CulDSac', 0.1624305902343901),
#  ('bsmt qual_Fa', -0.16149905190631852),
#  ('alley_Grvl', -0.15910857205745293),
#  ('exterior 2nd_CmentBd', 0.1569991094269623),
#  ('exter cond_Fa', -0.15589901221140548),
#  ('kitchen qual_Fa', -0.15487456612545633),
#  ('bsmtfin type 1_Rec', -0.15091467927234847),
#  ('fence_MnPrv', -0.150442363293801),
#  ('neighborhood_Somerst', 0.15007843077381233),
#  ('exterior 1st_MetalSd', -0.1498509690275754),
#  ('heating qc_Fa', -0.14922710144349344),
#  ('fireplace qu_TA', 0.14708387125253622),
#  ('bsmt cond_Fa', -0.14347185962094364),
#  ('garage cond_Fa', -0.14317607306156968),
#  ('exterior 2nd_MetalSd', -0.13933926266389154),
#  ('neighborhood_BrkSide', -0.13478960883185645),
#  ('neighborhood_Sawyer', -0.1336915097934506),
#  ('exter qual_Fa', -0.13108515345417607),
#  ('bsmtfin type 1_BLQ', -0.13010205464301858),
#  ('electrical_FuseF', -0.1293528801015948),
#  ('bsmt exposure_Av', 0.12646022863629325),
#  ('exterior 1st_AsbShng', -0.12634024452341427),
#  ('ms zoning_C (all)', -0.126252966684239),
#  ('condition 1_Artery', -0.1250303131024986),
#  ('bsmtfin type 1_Unf', -0.12471962683859007),
#  ('exter cond_TA', 0.12201440972201885),
#  ('foundation_Slab', -0.11905160471330693),
#  ('functional_Typ', 0.1176816770080278),
#  ('neighborhood_Timber', 0.11639970142249423),
#  ('heating qc_Gd', -0.11533797878535183),
#  ('condition 1_Feedr', -0.11434967267832681),
#  ('exterior 1st_HdBoard', -0.11433192069874501),
#  ('bsmt cond_Gd', 0.11423312718254058),
#  ('bsmtfin type 2_Unf', 0.11393708874016911),
#  ('bldg type_Twnhs', -0.11389516973745009),
#  ('neighborhood_MeadowV', -0.11155770246119198),
#  ('bldg type_2fmCon', -0.11142266635522004),
#  ('condition 1_Norm', 0.11135970035835985),
#  ('exterior 2nd_AsbShng', -0.1104038320755227),
#  ('lot shape_IR2', 0.10995014798703594),
#  ('sale type_COD', -0.10760019344899242),
#  ('condition 1_PosN', 0.10687730068639738),
#  ('ms zoning_FV', 0.10669527525723516),
#  ('bldg type_1Fam', 0.10570537457013836),
#  ('bldg type_Duplex', -0.10368946353434252),
#  ('condition 2_PosN', 0.10345896796563807),
#  ('exterior 2nd_HdBoard', -0.10246196185025686),
#  ('fence_GdWo', -0.10162507167135806),
#  ('condition 2_PosA', 0.10104392515824416),
#  ('roof matl_WdShngl', 0.09852735428656828),
#  ('land contour_Bnk', -0.09814283271293361),
#  ('garage qual_Gd', 0.09680296372579975),
#  ('neighborhood_BrDale', -0.09530543049480139),
#  ('heating_GasA', 0.09402713158457826),
#  ('bsmt cond_TA', 0.09363458708082313),
#  ('land contour_Lvl', -0.0928297029078813),
#  ('paved drive_P', -0.09074188432915128),
#  ('bsmtfin type 1_ALQ', -0.08810944053889731),
#  ('neighborhood_Veenker', 0.08318571796372008),
#  ('neighborhood_CollgCr', 0.08230884150815526),
#  ('lot config_Inside', -0.08219355563032057),
#  ('bsmtfin type 1_LwQ', -0.08142265586417517),
#  ('neighborhood_SWISU', -0.07421361041349328),
#  ('heating_Grav', -0.0725491988999957),
#  ('electrical_FuseP', -0.07236404922594172),
#  ('garage cond_Po', -0.07229415755106358),
#  ('garage type_CarPort', -0.07195490389830175),
#  ('heating_Wall', -0.07131066440222263),
#  ('condition 1_PosA', 0.07092994626982078),
#  ('street_Pave', 0.06984144401803435),
#  ('street_Grvl', -0.06984144401803434),
#  ('functional_Maj2', -0.06965216949929803),
#  ('roof matl_CompShg', -0.06910826711093286),
#  ('house style_1.5Unf', -0.06680506338160025),
#  ('fireplace qu_Po', -0.06598356800263545),
#  ('house style_SFoyer', -0.06408764870624875),
#  ('land slope_Gtl', -0.06260358852982953),
#  ('bldg type_TwnhsE', 0.06203719892029454),
#  ('land slope_Mod', 0.06191016760411416),
#  ('exterior 2nd_Wd Shng', -0.061163630081261494),
#  ('exterior 1st_Stucco', -0.06086426431654295),
#  ('sale type_ConLD', -0.06043102579675972),
#  ('exter cond_Gd', -0.059798139661553194),
#  ('exterior 2nd_Plywood', -0.05954107088378642),
#  ('functional_Sal', -0.059110128763311155),
#  ('neighborhood_Crawfor', 0.058385642044383956),
#  ('functional_Min2', -0.056648359793066094),
#  ('garage type_Basment', -0.05571988431804101),
#  ('heating qc_Po', -0.05430772849871424),
#  ('exter cond_Po', -0.05388593742816107),
#  ('condition 1_RRAe', -0.05363282672319459),
#  ('bsmtfin type 2_GLQ', 0.05353067013942625),
#  ('ms zoning_A (agr)', -0.05290024094983087),
#  ('neighborhood_ClearCr', 0.05250298614271504),
#  ('exterior 2nd_Stucco', -0.05188453757428996),
#  ('functional_Mod', -0.050420409416253455),
#  ('functional_Min1', -0.049340048640348085),
#  ('exterior 1st_WdShing', -0.04886623623863584),
#  ('bsmtfin type 2_BLQ', -0.048470556125923804),
#  ('condition 2_Feedr', -0.048455323655219366),
#  ('exterior 2nd_Brk Cmn', -0.04789278409638763),
#  ('misc feature_Shed', -0.047418993645449777),
#  ('neighborhood_NPkVill', -0.04729555368418458),
#  ('roof matl_WdShake', 0.04618035206066952),
#  ('garage qual_Po', -0.04592150988325304),
#  ('bsmtfin type 2_Rec', -0.04304693429415899),
#  ('exterior 2nd_ImStucc', 0.04263112888786575),
#  ('house style_2.5Fin', 0.04251648378645912),
#  ('house style_SLvl', -0.04209811664698723),
#  ('bsmtfin type 2_LwQ', -0.04203041263725202),
#  ('roof style_Gambrel', -0.04188335269666355),
#  ('fence_MnWw', -0.04090371607687491),
#  ('exter cond_Ex', 0.04046709137551997),
#  ('exterior 1st_Plywood', -0.039125472980729825),
#  ('condition 2_Artery', -0.038941533812984534),
#  ('neighborhood_GrnHill', 0.0388483872531445),
#  ('heating_GasW', -0.03781376805062891),
#  ('mas vnr type_BrkCmn', -0.037246916704239116),
#  ('pool qc_Ex', 0.03721877428882015),
#  ('bsmt cond_Po', -0.035813968440528546),
#  ('neighborhood_Mitchel', -0.035573867085953566),
#  ('sale type_ConLw', -0.03547907713518777),
#  ('exterior 2nd_CBlock', -0.035275987917286825),
#  ('neighborhood_NWAmes', 0.034926205275145214),
#  ('exterior 1st_CBlock', -0.03478313967812173),
#  ('ms zoning_I (all)', -0.03451911702131162),
#  ('utilities_NoSewr', -0.03451911702131162),
#  ('ms zoning_RH', -0.0341177367177436),
#  ('functional_Sev', -0.03379744319979153),
#  ('sale type_Con', 0.0336604340214046),
#  ('condition 2_RRNn', -0.03340316460845944),
#  ('utilities_AllPub', 0.03308281325300213),
#  ('land contour_Low', 0.03295258731881039),
#  ('electrical_Mix', -0.03190603210229274),
#  ('exterior 1st_Stone', 0.030371397539504724),
#  ('sale type_Oth', -0.030109141609156433),
#  ('garage type_2Types', -0.029636097585761585),
#  ('bsmt exposure_Mn', 0.029323205771956733),
#  ('garage qual_Ex', 0.028753643790253403),
#  ('exterior 1st_AsphShn', -0.02762057283510176),
#  ('garage cond_Gd', 0.02668321985046227),
#  ('exterior 1st_BrkFace', 0.026239827119873497),
#  ('bsmt qual_Po', -0.02577399282566176),
#  ('neighborhood_Blueste', -0.02522610685811112),
#  ('condition 1_RRNe', -0.0250454598157915),
#  ('neighborhood_Blmngtn', 0.024899602668028795),
#  ('exterior 2nd_Stone', -0.0246423311526574),
#  ('exterior 1st_BrkComm', -0.0243772979724125),
#  ('fireplace qu_Fa', -0.024287306529841016),
#  ('neighborhood_Gilbert', 0.023973744999377836),
#  ('foundation_Stone', -0.023853208183461955),
#  ('exterior 2nd_AsphShn', -0.02383391334074885),
#  ('garage cond_Ex', -0.022659072994660245),
#  ('exterior 1st_ImStucc', 0.022446134213300075),
#  ('heating_OthW', -0.021969085459829108),
#  ('house style_1Story', -0.021651702681707918),
#  ('roof style_Mansard', -0.021289470340622882),
#  ('sale type_ConLI', 0.019588128480110024),
#  ('pool qc_Gd', 0.019538044574418195),
#  ('misc feature_Gar2', -0.019508423660549),
#  ('misc feature_TenC', 0.01910138551695589),
#  ('functional_Maj1', -0.017778596503133973),
#  ('roof matl_Membran', 0.0167321885237121),
#  ('neighborhood_SawyerW', 0.016708229026771156),
#  ('pool qc_TA', -0.015759197646348817),
#  ('condition 1_RRAn', -0.01495367409241428),
#  ('lot config_FR2', -0.014823053915271228),
#  ('alley_Pave', -0.014528014035644505),
#  ('lot config_FR3', 0.014352167406570152),
#  ('pool qc_Fa', 0.013417418112225214),
#  ('roof style_Shed', 0.013136366969106151),
#  ('condition 2_RRAn', -0.0124214773007978),
#  ('neighborhood_Landmrk', -0.012394998040285071),
#  ('utilities_NoSeWa', -0.012255633511270741),
#  ('bsmtfin type 2_ALQ', 0.011801840531422187),
#  ('fence_GdPrv', -0.011636359764908353),
#  ('land slope_Sev', 0.011597012210420865),
#  ('condition 1_RRNn', 0.011442162228594134),
#  ('house style_2.5Unf', 0.010792934665853255),
#  ('exterior 2nd_BrkFace', 0.010687827448596596),
#  ('roof style_Flat', 0.010223774431188848),
#  ('lot shape_IR3', 0.009813025596933964),
#  ('condition 2_Norm', -0.009759291033829371),
#  ('misc feature_Othr', -0.008840522578178377),
#  ('roof matl_Tar&Grv', 0.007018421273166368),
#  ('bsmt cond_Ex', 0.006535249962229447),
#  ('roof matl_ClyTile', -0.0059842297056254086),
#  ('lot config_Corner', -0.004792669170791167),
#  ('sale type_CWD', 0.004562817413729858),
#  ('neighborhood_Greens', 0.0034761957395305202),
#  ('foundation_Wood', -0.0030437130758891816),
#  ('condition 2_RRAe', 0.002377642035235021),
#  ('misc feature_Elev', 0.0006634583283586335)]
# exter qual_TA: -0.600
# bsmt qual_Ex: 0.586
# kitchen qual_Ex: 0.551
# kitchen qual_TA: -0.541
# foundation_PConc: 0.529
# exter qual_Ex: 0.494
# bsmtfin type 1_GLQ: 0.464
# bsmt qual_TA: -0.457
# heating qc_Ex: 0.453
# neighborhood_NridgHt: 0.449
# exter qual_Gd: 0.447
# garage finish_Unf: -0.432
# mas vnr type_None: -0.424
# garage finish_Fin: 0.423
# fireplace qu_Gd: 0.385
# bsmt exposure_Gd: 0.377
# garage type_Detchd: -0.370
# sale type_New: 0.358
# garage type_Attchd: 0.358
# foundation_CBlock: -0.356
# heating qc_TA: -0.344
# exterior 1st_VinylSd: 0.342
# exterior 2nd_VinylSd: 0.338
# mas vnr type_Stone: 0.310
# lot shape_Reg: -0.306
# kitchen qual_Gd: 0.306
# bsmt exposure_No: -0.293
# paved drive_Y: 0.289
# ms zoning_RM: -0.282
# central air_Y: 0.277
# central air_N: -0.277
# paved drive_N: -0.274
# lot shape_IR1: 0.274
# garage cond_TA: 0.272
# roof style_Hip: 0.265
# neighborhood_NoRidge: 0.263
# mas vnr type_BrkFace: 0.258
# neighborhood_StoneBr: 0.257
# electrical_SBrkr: 0.254
# garage qual_TA: 0.250
# roof style_Gable: -0.249
# fireplace qu_Ex: 0.235
# ms zoning_RL: 0.231
# foundation_BrkTil: -0.230
# bsmt qual_Gd: 0.227
# garage type_BuiltIn: 0.220
# sale type_WD : -0.213
# land contour_HLS: 0.212
# neighborhood_OldTown: -0.208
# house style_2Story: 0.202
# electrical_FuseA: -0.201
# house style_1.5Fin: -0.196
# exterior 1st_Wd Sdng: -0.192
# neighborhood_NAmes: -0.189
# neighborhood_IDOTRR: -0.189
# garage finish_RFn: 0.185
# neighborhood_Edwards: -0.176
# exterior 2nd_Wd Sdng: -0.173
# garage qual_Fa: -0.168
# exterior 1st_CemntBd: 0.168
# lot config_CulDSac: 0.162
# bsmt qual_Fa: -0.161
# alley_Grvl: -0.159
# exterior 2nd_CmentBd: 0.157
# exter cond_Fa: -0.156
# kitchen qual_Fa: -0.155
# bsmtfin type 1_Rec: -0.151
# fence_MnPrv: -0.150
# neighborhood_Somerst: 0.150
# exterior 1st_MetalSd: -0.150
# heating qc_Fa: -0.149
# fireplace qu_TA: 0.147
# bsmt cond_Fa: -0.143
# garage cond_Fa: -0.143
# exterior 2nd_MetalSd: -0.139
# neighborhood_BrkSide: -0.135
# neighborhood_Sawyer: -0.134
# exter qual_Fa: -0.131
# bsmtfin type 1_BLQ: -0.130
# electrical_FuseF: -0.129
# bsmt exposure_Av: 0.126
# exterior 1st_AsbShng: -0.126
# ms zoning_C (all): -0.126
# condition 1_Artery: -0.125
# bsmtfin type 1_Unf: -0.125
# exter cond_TA: 0.122
# foundation_Slab: -0.119
# functional_Typ: 0.118
# neighborhood_Timber: 0.116
# heating qc_Gd: -0.115
# condition 1_Feedr: -0.114
# exterior 1st_HdBoard: -0.114
# bsmt cond_Gd: 0.114
# bsmtfin type 2_Unf: 0.114
# bldg type_Twnhs: -0.114
# neighborhood_MeadowV: -0.112
# bldg type_2fmCon: -0.111
# condition 1_Norm: 0.111
# exterior 2nd_AsbShng: -0.110
# lot shape_IR2: 0.110
# sale type_COD: -0.108
# condition 1_PosN: 0.107
# ms zoning_FV: 0.107
# bldg type_1Fam: 0.106
# bldg type_Duplex: -0.104
# condition 2_PosN: 0.103
# exterior 2nd_HdBoard: -0.102
# fence_GdWo: -0.102
# condition 2_PosA: 0.101
# roof matl_WdShngl: 0.099
# land contour_Bnk: -0.098
# garage qual_Gd: 0.097
# neighborhood_BrDale: -0.095
# heating_GasA: 0.094
# bsmt cond_TA: 0.094
# land contour_Lvl: -0.093
# paved drive_P: -0.091
# bsmtfin type 1_ALQ: -0.088
# neighborhood_Veenker: 0.083
# neighborhood_CollgCr: 0.082
# lot config_Inside: -0.082
# bsmtfin type 1_LwQ: -0.081
# neighborhood_SWISU: -0.074
# heating_Grav: -0.073
# electrical_FuseP: -0.072
# garage cond_Po: -0.072
# garage type_CarPort: -0.072
# heating_Wall: -0.071
# condition 1_PosA: 0.071
# street_Pave: 0.070
# street_Grvl: -0.070
# functional_Maj2: -0.070
# roof matl_CompShg: -0.069
# house style_1.5Unf: -0.067
# fireplace qu_Po: -0.066
# house style_SFoyer: -0.064
# land slope_Gtl: -0.063
# bldg type_TwnhsE: 0.062
# land slope_Mod: 0.062
# exterior 2nd_Wd Shng: -0.061
# exterior 1st_Stucco: -0.061
# sale type_ConLD: -0.060
# exter cond_Gd: -0.060
# exterior 2nd_Plywood: -0.060
# functional_Sal: -0.059
# neighborhood_Crawfor: 0.058
# functional_Min2: -0.057
# garage type_Basment: -0.056
# heating qc_Po: -0.054
# exter cond_Po: -0.054
# condition 1_RRAe: -0.054
# bsmtfin type 2_GLQ: 0.054
# ms zoning_A (agr): -0.053
# neighborhood_ClearCr: 0.053
# exterior 2nd_Stucco: -0.052
# functional_Mod: -0.050
# functional_Min1: -0.049
# exterior 1st_WdShing: -0.049
# bsmtfin type 2_BLQ: -0.048
# condition 2_Feedr: -0.048
# exterior 2nd_Brk Cmn: -0.048
# misc feature_Shed: -0.047
# neighborhood_NPkVill: -0.047
# roof matl_WdShake: 0.046
# garage qual_Po: -0.046
# bsmtfin type 2_Rec: -0.043
# exterior 2nd_ImStucc: 0.043
# house style_2.5Fin: 0.043
# house style_SLvl: -0.042
# bsmtfin type 2_LwQ: -0.042
# roof style_Gambrel: -0.042
# fence_MnWw: -0.041
# exter cond_Ex: 0.040
# exterior 1st_Plywood: -0.039
# condition 2_Artery: -0.039
# neighborhood_GrnHill: 0.039
# heating_GasW: -0.038
# mas vnr type_BrkCmn: -0.037
# pool qc_Ex: 0.037
# bsmt cond_Po: -0.036
# neighborhood_Mitchel: -0.036
# sale type_ConLw: -0.035
# exterior 2nd_CBlock: -0.035
# neighborhood_NWAmes: 0.035
# exterior 1st_CBlock: -0.035
# ms zoning_I (all): -0.035
# utilities_NoSewr: -0.035
# ms zoning_RH: -0.034
# functional_Sev: -0.034
# sale type_Con: 0.034
# condition 2_RRNn: -0.033
# utilities_AllPub: 0.033
# land contour_Low: 0.033
# electrical_Mix: -0.032
# exterior 1st_Stone: 0.030
# sale type_Oth: -0.030
# garage type_2Types: -0.030
# bsmt exposure_Mn: 0.029
# garage qual_Ex: 0.029
# exterior 1st_AsphShn: -0.028
# garage cond_Gd: 0.027
# exterior 1st_BrkFace: 0.026
# bsmt qual_Po: -0.026
# neighborhood_Blueste: -0.025
# condition 1_RRNe: -0.025
# neighborhood_Blmngtn: 0.025
# exterior 2nd_Stone: -0.025
# exterior 1st_BrkComm: -0.024
# fireplace qu_Fa: -0.024
# neighborhood_Gilbert: 0.024
# foundation_Stone: -0.024
# exterior 2nd_AsphShn: -0.024
# garage cond_Ex: -0.023
# exterior 1st_ImStucc: 0.022
# heating_OthW: -0.022
# house style_1Story: -0.022
# roof style_Mansard: -0.021
# sale type_ConLI: 0.020
# pool qc_Gd: 0.020
# misc feature_Gar2: -0.020
# misc feature_TenC: 0.019
# functional_Maj1: -0.018
# roof matl_Membran: 0.017
# neighborhood_SawyerW: 0.017
# pool qc_TA: -0.016
# condition 1_RRAn: -0.015
# lot config_FR2: -0.015
# alley_Pave: -0.015
# lot config_FR3: 0.014
# pool qc_Fa: 0.013
# roof style_Shed: 0.013
# condition 2_RRAn: -0.012
# neighborhood_Landmrk: -0.012
# utilities_NoSeWa: -0.012
# bsmtfin type 2_ALQ: 0.012
# fence_GdPrv: -0.012
# land slope_Sev: 0.012
# condition 1_RRNn: 0.011
# house style_2.5Unf: 0.011
# exterior 2nd_BrkFace: 0.011
# roof style_Flat: 0.010
# lot shape_IR3: 0.010
# condition 2_Norm: -0.010
# misc feature_Othr: -0.009
# roof matl_Tar&Grv: 0.007
# bsmt cond_Ex: 0.007
# roof matl_ClyTile: -0.006
# lot config_Corner: -0.005
# sale type_CWD: 0.005
# neighborhood_Greens: 0.003
# foundation_Wood: -0.003
# condition 2_RRAe: 0.002
# misc feature_Elev: 0.001

# %% [markdown]
# As we can see, the encoded categorical features are less correlated individually than the continuous features. We'll select the top 6 features to evalate.

# %%
corr_cat_list = [item[0] for item in sorted_features]

# %%
# let's change the input encoded df for both test and train to adjust for this change

#train
train_encoded = train_encoded.loc[:, train_encoded.columns.isin(corr_cat_list)]

#test
test_encoded = test_encoded.loc[:, test_encoded.columns.isin(corr_cat_list)]

# %% [markdown]
# ##### Combined Result Dataframe
#
# Now that we've adequately standardized the features of our dataframe, we'll combine the scaled and encoded continuous & categorical dataframes together

# %%
#train
df = pd.concat([df_scaled,train_encoded],axis = 1)
df['saleprice'] = price_col

#test
df_test = pd.concat([df_scaled_test,test_encoded],axis = 1)

# %% [markdown]
# #### Last removal of missing values
#
# It's possible that some missing values were created during the processing phase. I'll use this space to ensure no missing values enter the model.

# %%
# create a Boolean mask indicating where NaN values are
num_missing_per_col = df.isna().sum()

# count the number of NaN values in each column
cols_with_missing_values = df.loc[:, num_missing_per_col > 0]

# Dropping last row which is showing up as zeros
df= df.drop(df.index[-1])

#train
df = df.fillna(0)

#test
df_test = df_test.fillna(0)

# %%
# create a Boolean mask indicating where NaN values are
num_missing_per_col = df.isna().sum()

# count the number of NaN values in each column
cols_with_missing_values = df.loc[:, num_missing_per_col > 0]

display(cols_with_missing_values.columns)
# Out:
# Index([], dtype='object')

# %%
# exporting df_cat and df_cont

#setting up pickle to export variables
with open('pickles/cat_cols_encoded.pkl', 'wb') as f:
    pickle.dump(cat_cols_encoded, f)
       
with open('pickles/cat_cols.pkl', 'wb') as f:
    pickle.dump(cat_cols, f)
    
with open('pickles/df.pkl', 'wb') as f:
    pickle.dump(df, f)
      
with open('pickles/df_test.pkl', 'wb') as f:
    pickle.dump(df_test, f)
    
with open('pickles/scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
